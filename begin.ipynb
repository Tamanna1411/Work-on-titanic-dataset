# %%
import numpy as np
import pandas as pd

# %%
content=pd.read_csv('titanic_test.csv')

# %%
content
# Out:
#      passenger_id  pclass                            name     sex   age  \
# 0             295       1     Thayer, Mr. John Borland Jr    male  17.0
# 1            1150       3        Risien, Mr. Samuel Beard    male   NaN
# 2              89       1          Davidson, Mr. Thornton    male  31.0
# 3            1063       3  Nirva, Mr. Iisakki Antino Aijo    male  41.0
# 4            1020       3              Minkoff, Mr. Lazar    male  21.0
# ..            ...     ...                             ...     ...   ...
# 454          1194       3              Sdycoff, Mr. Todor    male   NaN
# 455           403       2    Eitemiller, Mr. George Floyd    male  23.0
# 456           108       1         Fleming, Miss. Margaret  female   NaN
# 457           510       2        Mudd, Mr. Thomas Charles    male  16.0
# 458          1265       3       Van Impe, Miss. Catharina  female  10.0
#
#      sibsp  parch            ticket      fare cabin embarked boat  body  \
# ...

# %%
type(content)
# Out:
# pandas.core.frame.DataFrame

# %%
content.head(3)
# Out:
#    passenger_id  pclass                         name   sex   age  sibsp  \
# 0           295       1  Thayer, Mr. John Borland Jr  male  17.0      0
# 1          1150       3     Risien, Mr. Samuel Beard  male   NaN      0
# 2            89       1       Davidson, Mr. Thornton  male  31.0      1
#
#    parch      ticket      fare cabin embarked boat  body      home.dest
# 0      2       17421  110.8833   C70        C    B   NaN  Haverford, PA
# 1      0      364498   14.5000   NaN        S  NaN   NaN            NaN
# 2      0  F.C. 12750   52.0000   B71        S  NaN   NaN   Montreal, PQ

# %%
single_id=content[content.passenger_id==89]

# %%
single_id
# Out:
#    passenger_id  pclass                    name   sex   age  sibsp  parch  \
# 2            89       1  Davidson, Mr. Thornton  male  31.0      1      0
#
#        ticket  fare cabin embarked boat  body     home.dest
# 2  F.C. 12750  52.0   B71        S  NaN   NaN  Montreal, PQ

# %%
single_column=content[['name']].head(3)

# %%
single_column
# Out:
#                           name
# 0  Thayer, Mr. John Borland Jr
# 1     Risien, Mr. Samuel Beard
# 2       Davidson, Mr. Thornton

# %%
content.loc[0:8,['passenger_id','name','sex']]
# Out:
#    passenger_id                                     name     sex
# 0           295              Thayer, Mr. John Borland Jr    male
# 1          1150                 Risien, Mr. Samuel Beard    male
# 2            89                   Davidson, Mr. Thornton    male
# 3          1063           Nirva, Mr. Iisakki Antino Aijo    male
# 4          1020                       Minkoff, Mr. Lazar    male
# 5           747  Danbom, Master. Gilbert Sigvard Emanuel    male
# 6           368                  Chapman, Mr. John Henry    male
# 7          1047         Najib, Miss. Adele Kiamie "Jane"  female
# 8           569              Sweet, Mr. George Frederick    male

# %%
content.describe()
# Out:
#        passenger_id      pclass         age       sibsp       parch  \
# count    459.000000  459.000000  370.000000  459.000000  459.000000
# mean     637.673203    2.248366   30.541216    0.455338    0.389978
# std      372.769720    0.835467   14.133361    0.896176    0.840038
# min        0.000000    1.000000    0.333300    0.000000    0.000000
# 25%      317.000000    1.000000   21.250000    0.000000    0.000000
# 50%      612.000000    3.000000   29.000000    0.000000    0.000000
# 75%      960.000000    3.000000   40.000000    1.000000    0.000000
# max     1308.000000    3.000000   71.000000    8.000000    6.000000
#
#              fare        body
# count  459.000000   48.000000
# mean    31.968854  153.187500
# std     47.977896   96.104034
# min      0.000000    1.000000
# 25%      7.925000   69.250000
# 50%     14.500000  142.500000
# 75%     31.387500  250.500000
# max    512.329200  322.000000

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import os

# %%
print(os.listdir())
# Out:
# ['.ipynb_checkpoints', '.ipython', '.jupyter', '.matplotlib', '3D Objects', 'anaconda3', 'AppData', 'Application Data', 'begin.ipynb', 'Contacts', 'Cookies', 'Desktop', 'Documents', 'Downloads', 'Favorites', 'IntelGraphicsProfiles', 'Links', 'Local Settings', 'MicrosoftEdgeBackups', 'Music', 'My Documents', 'NetHood', 'NTUSER.DAT', 'ntuser.dat.LOG1', 'ntuser.dat.LOG2', 'NTUSER.DAT{fd9a35db-49fe-11e9-aa2c-248a07783950}.TM.blf', 'NTUSER.DAT{fd9a35db-49fe-11e9-aa2c-248a07783950}.TMContainer00000000000000000001.regtrans-ms', 'NTUSER.DAT{fd9a35db-49fe-11e9-aa2c-248a07783950}.TMContainer00000000000000000002.regtrans-ms', 'ntuser.ini', 'OneDrive', 'Pictures', 'PrintHood', 'Recent', 'Saved Games', 'Searches', 'SendTo', 'Start Menu', 'Templates', 'titanic_test.csv', 'titanic_train.csv', 'Videos']

# %%
content=pd.read_csv('titanic_test.csv')

# %%
content
# Out:
#      passenger_id  pclass                            name     sex   age  \
# 0             295       1     Thayer, Mr. John Borland Jr    male  17.0
# 1            1150       3        Risien, Mr. Samuel Beard    male   NaN
# 2              89       1          Davidson, Mr. Thornton    male  31.0
# 3            1063       3  Nirva, Mr. Iisakki Antino Aijo    male  41.0
# 4            1020       3              Minkoff, Mr. Lazar    male  21.0
# ..            ...     ...                             ...     ...   ...
# 454          1194       3              Sdycoff, Mr. Todor    male   NaN
# 455           403       2    Eitemiller, Mr. George Floyd    male  23.0
# 456           108       1         Fleming, Miss. Margaret  female   NaN
# 457           510       2        Mudd, Mr. Thomas Charles    male  16.0
# 458          1265       3       Van Impe, Miss. Catharina  female  10.0
#
#      sibsp  parch            ticket      fare cabin embarked boat  body  \
# ...

# %%
content.isnull().sum()
# Out:
# passenger_id      0
# pclass            0
# name              0
# sex               0
# age              89
# sibsp             0
# parch             0
# ticket            0
# fare              0
# cabin           355
# embarked          1
# boat            281
# body            411
# home.dest       178
# dtype: int64

# %%
missing_values=["n/a","na",np.nan]
content=pd.read_csv('titanic_test.csv',na_values=missing_values)

# %%
content.isnull().sum().sum()
# Out:
# 1315

# %%
content.isnull().any()
# Out:
# passenger_id    False
# pclass          False
# name            False
# sex             False
# age              True
# sibsp           False
# parch           False
# ticket          False
# fare            False
# cabin            True
# embarked         True
# boat             True
# body             True
# home.dest        True
# dtype: bool

# %%
sns.heatmap(content.isnull(),yticklabels=False, annot=True)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import os
import matplotlib.pyplot as plt
import sys

# %%
content=pd.read_csv('titanic_train.csv')

# %%
content
# Out:
#      passenger_id  pclass                                               name  \
# 0            1216       3                                 Smyth, Miss. Julia
# 1             699       3                                    Cacic, Mr. Luka
# 2            1267       3  Van Impe, Mrs. Jean Baptiste (Rosalie Paula Go...
# 3             449       2              Hocking, Mrs. Elizabeth (Eliza Needs)
# 4             576       2                                    Veal, Mr. James
# ..            ...     ...                                                ...
# 845           158       1                        Hipkins, Mr. William Edward
# 846           174       1                            Kent, Mr. Edward Austin
# 847           467       2                Kantor, Mrs. Sinai (Miriam Sternin)
# 848          1112       3                          Peacock, Miss. Treasteall
# 849           425       2                              Greenberg, Mr. Samuel
#
# ...

# %%
content.dropna()
# Out:
# Empty DataFrame
# Columns: [passenger_id, pclass, name, sex, age, sibsp, parch, ticket, fare, cabin, embarked, boat, body, home.dest, survived]
# Index: []

# %%
content.isnull().sum()
# Out:
# passenger_id      0
# pclass            0
# name              0
# sex               0
# age             174
# sibsp             0
# parch             0
# ticket            0
# fare              1
# cabin           659
# embarked          1
# boat            542
# body            777
# home.dest       386
# survived          0
# dtype: int64

# %%
content.fillna(0)
# Out:
#      passenger_id  pclass                                               name  \
# 0            1216       3                                 Smyth, Miss. Julia
# 1             699       3                                    Cacic, Mr. Luka
# 2            1267       3  Van Impe, Mrs. Jean Baptiste (Rosalie Paula Go...
# 3             449       2              Hocking, Mrs. Elizabeth (Eliza Needs)
# 4             576       2                                    Veal, Mr. James
# ..            ...     ...                                                ...
# 845           158       1                        Hipkins, Mr. William Edward
# 846           174       1                            Kent, Mr. Edward Austin
# 847           467       2                Kantor, Mrs. Sinai (Miriam Sternin)
# 848          1112       3                          Peacock, Miss. Treasteall
# 849           425       2                              Greenberg, Mr. Samuel
#
# ...

# %%
content.isnull().sum()
# Out:
# passenger_id      0
# pclass            0
# name              0
# sex               0
# age             174
# sibsp             0
# parch             0
# ticket            0
# fare              1
# cabin           659
# embarked          1
# boat            542
# body            777
# home.dest       386
# survived          0
# dtype: int64

# %%
content.fillna(method='ffill')
# Out:
#      passenger_id  pclass                                               name  \
# 0            1216       3                                 Smyth, Miss. Julia
# 1             699       3                                    Cacic, Mr. Luka
# 2            1267       3  Van Impe, Mrs. Jean Baptiste (Rosalie Paula Go...
# 3             449       2              Hocking, Mrs. Elizabeth (Eliza Needs)
# 4             576       2                                    Veal, Mr. James
# ..            ...     ...                                                ...
# 845           158       1                        Hipkins, Mr. William Edward
# 846           174       1                            Kent, Mr. Edward Austin
# 847           467       2                Kantor, Mrs. Sinai (Miriam Sternin)
# 848          1112       3                          Peacock, Miss. Treasteall
# 849           425       2                              Greenberg, Mr. Samuel
#
# ...

# %%
content.fillna(method='bfill')
# Out:
#      passenger_id  pclass                                               name  \
# 0            1216       3                                 Smyth, Miss. Julia
# 1             699       3                                    Cacic, Mr. Luka
# 2            1267       3  Van Impe, Mrs. Jean Baptiste (Rosalie Paula Go...
# 3             449       2              Hocking, Mrs. Elizabeth (Eliza Needs)
# 4             576       2                                    Veal, Mr. James
# ..            ...     ...                                                ...
# 845           158       1                        Hipkins, Mr. William Edward
# 846           174       1                            Kent, Mr. Edward Austin
# 847           467       2                Kantor, Mrs. Sinai (Miriam Sternin)
# 848          1112       3                          Peacock, Miss. Treasteall
# 849           425       2                              Greenberg, Mr. Samuel
#
# ...

# %%
content.isnull().sum()
# Out:
# passenger_id      0
# pclass            0
# name              0
# sex               0
# age             174
# sibsp             0
# parch             0
# ticket            0
# fare              1
# cabin           659
# embarked          1
# boat            542
# body            777
# home.dest       386
# survived          0
# dtype: int64

# %%
content.interpolate()
# Out:
#      passenger_id  pclass                                               name  \
# 0            1216       3                                 Smyth, Miss. Julia
# 1             699       3                                    Cacic, Mr. Luka
# 2            1267       3  Van Impe, Mrs. Jean Baptiste (Rosalie Paula Go...
# 3             449       2              Hocking, Mrs. Elizabeth (Eliza Needs)
# 4             576       2                                    Veal, Mr. James
# ..            ...     ...                                                ...
# 845           158       1                        Hipkins, Mr. William Edward
# 846           174       1                            Kent, Mr. Edward Austin
# 847           467       2                Kantor, Mrs. Sinai (Miriam Sternin)
# 848          1112       3                          Peacock, Miss. Treasteall
# 849           425       2                              Greenberg, Mr. Samuel
#
# ...

# %%
content.isnull().sum()
# Out:
# passenger_id      0
# pclass            0
# name              0
# sex               0
# age             174
# sibsp             0
# parch             0
# ticket            0
# fare              1
# cabin           659
# embarked          1
# boat            542
# body            777
# home.dest       386
# survived          0
# dtype: int64

# %%
content_drop=content.interpolate()

# %%
content_drop
# Out:
#      passenger_id  pclass                                               name  \
# 0            1216       3                                 Smyth, Miss. Julia
# 1             699       3                                    Cacic, Mr. Luka
# 2            1267       3  Van Impe, Mrs. Jean Baptiste (Rosalie Paula Go...
# 3             449       2              Hocking, Mrs. Elizabeth (Eliza Needs)
# 4             576       2                                    Veal, Mr. James
# ..            ...     ...                                                ...
# 845           158       1                        Hipkins, Mr. William Edward
# 846           174       1                            Kent, Mr. Edward Austin
# 847           467       2                Kantor, Mrs. Sinai (Miriam Sternin)
# 848          1112       3                          Peacock, Miss. Treasteall
# 849           425       2                              Greenberg, Mr. Samuel
#
# ...

# %%
content_drop.isnull().sum()
# Out:
# passenger_id      0
# pclass            0
# name              0
# sex               0
# age               1
# sibsp             0
# parch             0
# ticket            0
# fare              0
# cabin           659
# embarked          1
# boat            542
# body              5
# home.dest       386
# survived          0
# dtype: int64

# %%
content_drop.fillna({
    'cabin':"B72",
    'boat':'C',
    'body':271,
    'home.dest':"anywhere"
})
# Out:
#      passenger_id  pclass                                               name  \
# 0            1216       3                                 Smyth, Miss. Julia
# 1             699       3                                    Cacic, Mr. Luka
# 2            1267       3  Van Impe, Mrs. Jean Baptiste (Rosalie Paula Go...
# 3             449       2              Hocking, Mrs. Elizabeth (Eliza Needs)
# 4             576       2                                    Veal, Mr. James
# ..            ...     ...                                                ...
# 845           158       1                        Hipkins, Mr. William Edward
# 846           174       1                            Kent, Mr. Edward Austin
# 847           467       2                Kantor, Mrs. Sinai (Miriam Sternin)
# 848          1112       3                          Peacock, Miss. Treasteall
# 849           425       2                              Greenberg, Mr. Samuel
#
# ...

# %%
content_drop.columns
# Out:
# Index(['passenger_id', 'pclass', 'name', 'sex', 'age', 'sibsp', 'parch',
#        'ticket', 'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest',
#        'survived'],
#       dtype='object')

# %%
content_drop.isnull().sum()
# Out:
# passenger_id      0
# pclass            0
# name              0
# sex               0
# age               1
# sibsp             0
# parch             0
# ticket            0
# fare              0
# cabin           659
# embarked          1
# boat            542
# body              5
# home.dest       386
# survived          0
# dtype: int64

# %%
content_drop.describe()
# Out:
#        passenger_id     pclass         age       sibsp       parch  \
# count    850.000000  850.00000  849.000000  850.000000  850.000000
# mean     662.816471    2.32000   29.532440    0.522353    0.382353
# std      380.751936    0.83853   13.592609    1.112132    0.879511
# min        1.000000    1.00000    0.166700    0.000000    0.000000
# 25%      332.250000    2.00000   21.000000    0.000000    0.000000
# 50%      676.500000    3.00000   28.000000    0.000000    0.000000
# 75%      992.250000    3.00000   36.000000    1.000000    0.000000
# max     1307.000000    3.00000   80.000000    8.000000    9.000000
#
#              fare        body    survived
# count  850.000000  845.000000  850.000000
# mean    33.997291  170.534320    0.368235
# std     53.676021   77.893215    0.482610
# min      0.000000    4.000000    0.000000
# 25%      7.895800  110.600000    0.000000
# 50%     14.108300  158.481481    0.000000
# 75%     30.923950  231.675676    1.000000
# ...

# %%
single_column=content[['survived']].head(20)

# %%
# value counts for survival passenger
content_drop['survived'].value_counts()
# Out:
# 0    537
# 1    313
# Name: survived, dtype: int64

# %% [raw]
# sns.countplot(content_drop['survived'])

# %%
#visualize countplot of survivors for 'sex','pclass', 'age', 'sibsp', 'parch','embarked'
columns=['sex','pclass', 'age', 'sibsp', 'parch','embarked']
n_rows=2
n_cols=3
#subplot grid  and figure size of every attribute
fig,axs=plt.subplots(n_rows,n_cols,figsize=(n_cols*4.3,n_rows*3.2))

for r in range(0,n_rows):
    for c in range(0,n_cols):
        
        #index to go through with column
        i=r*n_cols+c
        # position of each plot
        ax=axs[r][c]
        sns.countplot(content_drop[columns[i]], hue=content_drop['survived'], ax=ax)
        ax.set_title(columns[i])
        ax.legend(title='survived',loc='upper right')
        
        plt.tight_layout()

# %%
#survival rate by sex
content_drop.groupby('sex')[['survived']].mean()
# Out:
#         survived
# sex
# female  0.702341
# male    0.186933

# %%
# survival rate by sex and pclass
content_drop.pivot_table('survived',index='sex',columns='pclass')
# Out:
# pclass         1         2         3
# sex
# female  0.946809  0.895522  0.442029
# male    0.321429  0.161616  0.150000

# %%
content_drop.pivot_table('survived',index='sex',columns='pclass').plot()

# %%
#survival rate of each pclass
sns.barplot(x='pclass',y='survived',data=content_drop)

# %%
#survival rate for sex,age,pclass
age=pd.cut(content_drop['age'],[0,20,80])
content_drop.pivot_table('survived',index=['sex','age'],columns='pclass')
# Out:
# pclass            1    2    3
# sex    age
# female 0.1667   NaN  NaN  1.0
#        1.0000   NaN  NaN  0.5
#        2.0000   0.0  1.0  0.0
#        3.0000   NaN  1.0  0.0
#        4.0000   NaN  1.0  1.0
# ...             ...  ...  ...
# male   65.0000  0.0  NaN  0.0
#        67.0000  0.0  NaN  NaN
#        70.0000  0.0  0.0  NaN
#        74.0000  NaN  NaN  0.0
#        80.0000  1.0  NaN  NaN
#
# [230 rows x 3 columns]

# %%
#price per class plot
plt.scatter(content_drop['fare'],content_drop['pclass'],color='red',label='pessenger paid')
plt.xlabel('fare')
plt.ylabel('pclass')
plt.title('each pessenger fare per pclass')
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
content_drop.isnull().sum()
# Out:
# passenger_id      0
# pclass            0
# name              0
# sex               0
# age               1
# sibsp             0
# parch             0
# ticket            0
# fare              0
# cabin           659
# embarked          1
# boat            542
# body              5
# home.dest       386
# survived          0
# dtype: int64

# %%
for val in content_drop:
    print(content_drop[val].value_counts())
    print()
# Out:
# 1307    1
# 458     1
# 455     1
# 453     1
# 452     1
#        ..
# 880     1
# 879     1
# 878     1
# 877     1
# 1       1
# Name: passenger_id, Length: 850, dtype: int64
#
# 3    478
# 1    206
# 2    166
# Name: pclass, dtype: int64
#
# Kelly, Mr. James                                  2
# Molson, Mr. Harry Markland                        1
# Bourke, Miss. Mary                                1
# Vander Planke, Miss. Augusta Maria                1
# del Carlo, Mrs. Sebastiano (Argenia Genovesi)     1
#                                                  ..
# Rothschild, Mrs. Martin (Elizabeth L. Barrett)    1
# Danbom, Mr. Ernst Gilbert                         1
# O'Sullivan, Miss. Bridget Mary                    1
# Henriksson, Miss. Jenny Lovisa                    1
# Smith, Mrs. Lucien Philip (Mary Eloise Hughes)    1
# Name: name, Length: 849, dtype: int64
#
# male      551
# female    299
# Name: sex, dtype: int64
#
# 30.000000    35
# 18.000000    32
# 25.000000    31
# ...

# %%
#remove missing rows of perticuler column
titanic=content_drop.dropna(subset =['age','embarked','cabin','boat','body','home.dest'])

# %%
titanic.shape
# Out:
# (109, 15)

# %%
titanic.dtypes
# Out:
# passenger_id      int64
# pclass            int64
# name             object
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# ticket           object
# fare            float64
# cabin            object
# embarked         object
# boat             object
# body            float64
# home.dest        object
# survived          int64
# dtype: object

# %%
#for unique value
print(titanic["sex"].unique())
print(titanic["embarked"].unique())
# Out:
# ['female' 'male']
# ['C' 'S' 'Q']

# %%
#encoding object value to numeric
from sklearn.preprocessing import LabelEncoder

labelencoder = LabelEncoder()

titanic.iloc[:,2]=labelencoder.fit_transform(titanic.iloc[:,2].values)

titanic.iloc[:,3]=labelencoder.fit_transform(titanic.iloc[:,3].values)

titanic.iloc[:,7]=labelencoder.fit_transform(titanic.iloc[:,7].values)

titanic.iloc[:,9]=labelencoder.fit_transform(titanic.iloc[:,9].values)

titanic.iloc[:,10]=labelencoder.fit_transform(titanic.iloc[:,10].values)

titanic.iloc[:,11]=labelencoder.fit_transform(titanic.iloc[:,11].values)

titanic.iloc[:,13]=labelencoder.fit_transform(titanic.iloc[:,13].values)
# Out:
# C:\Users\DCL\anaconda3\lib\site-packages\pandas\core\indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
print(titanic["name"].unique())

print(titanic["sex"].unique())

print(titanic["ticket"].unique())

print(titanic["cabin"].unique())

print(titanic["embarked"].unique())

print(titanic["boat"].unique())

print(titanic["home.dest"].unique())
# Out:
# [ 20  84  17  86  97  53  24  22  96  26 102 101  82  63  67  42 106  71
#   37  12  29  35  69   7   5  59   9  14  11  46  56   2  50  43  25  58
#   74  30  52 100  87  83  16  51  88  23  79   8  39  55  99  41   0  94
#   95  31  10  36  85  98  32  81  72  49  18  76  65  80  33  57  75   4
#   90  60 108  78  54  48  15  77  47 107 104  68  93  70  13  19  38   1
#   91  28  34  61  66 105 103   3  21  64  92  89  40  45  27  44   6  73
#   62]
# [0 1]
# [23 20  8 74 34 70  9 75 35 47 78  4 37 80 60 64  6 52 72  5 51 54 66  3
#  26 24 17 44 62 45 31 67 25 28 11 38 13 15 18 68 57 69 61 58 14 33 76 50
#  73  0 27 83 63 42 32 53 49 48 82 22 77 46 79 59 19 40  1  7 55 71 30 10
#  21 39 12 16 84 29 36  2 81 65 41 56 43]
# [51 34 70 17 71 26 21 15 41 27 40 16 52 47 42 69 67 64  4  8 13  1  9  5
#  38 12 58 29 45 66 11  0 19 43 35 23 25 63 18  2 57 53 76  3 31 73 79 46
#  20 14 78 10 77 65 61 22 37 39 24 32 59 74 62 36 44 55 72 56  6 28 30 75
#   7 50 54 60 49 68 33 48]
# [0 2 1]
# ...

# %%
titanic.dtypes
# Out:
# passenger_id      int64
# pclass            int64
# name              int32
# sex               int32
# age             float64
# sibsp             int64
# parch             int64
# ticket            int32
# fare            float64
# cabin             int32
# embarked          int32
# boat              int32
# body            float64
# home.dest         int32
# survived          int64
# dtype: object

# %%
# split data into independent and dependent
X = titanic.iloc[:,0:13].values
Y= titanic.iloc[:,14].values

# %%
X.shape,Y.shape
# Out:
# ((109, 13), (109,))

# %%
#split dataset into train(0.7)and test (0.3)
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=5)

# %%
Y_train.shape,Y_test.shape
# Out:
# ((87,), (22,))

# %%
#scale the data
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.fit_transform(X_test)

# %%
import matplotlib.pyplot as plt
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
  
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
#logistic regression
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix,accuracy_score
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
import itertools
log=LogisticRegression ()
log.fit(X_train,Y_train)
predictions=log.predict(X_test)
#predictions = model.predict(x_test)
print('Classification Report:\n',classification_report(Y_test, predictions))
print('Confusion Matrix:\n',confusion_matrix(Y_test, predictions))
print('Accuracy Score:',accuracy_score(Y_test, predictions))
print("Precision:",metrics.precision_score(Y_test, predictions))
print("Recall:",metrics.recall_score(Y_test,predictions ))
cm = metrics.confusion_matrix(Y_test, predictions)
plot_confusion_matrix(cm, classes=['FAKE Data', 'REAL Data'])
#metrics.accuracy_score(Y_test,predictions)
#print('logistic linear regression accuracy:', log.score(X_train,Y_train))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        22
#
#     accuracy                           1.00        22
#    macro avg       1.00      1.00      1.00        22
# weighted avg       1.00      1.00      1.00        22
#
# Confusion Matrix:
#  [[22]]
# Accuracy Score: 1.0
# Precision: 1.0
# Recall: 1.0
# Confusion matrix, without normalization

# %%
from sklearn.model_selection import cross_val_score
log=LogisticRegression ()
print(cross_val_score(log,X,Y,cv=5,scoring='accuracy').mean())
# Out:
# nan
# C:\Users\DCL\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:670: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(("The least populated class in y has only %d"
# C:\Users\DCL\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\DCL\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# ...

# %%
#predictions=log.predict(X_test)
from sklearn.metrics import classification_report
classification_report (Y_test,predictions)
# Out:
# '              precision    recall  f1-score   support\n\n           1       1.00      1.00      1.00        22\n\n    accuracy                           1.00        22\n   macro avg       1.00      1.00      1.00        22\nweighted avg       1.00      1.00      1.00        22\n'

# %%
print('Classification Report:\n',classification_report(Y_test, predictions))
print('Confusion Matrix:\n',confusion_matrix(Y_test, predictions))
print('Accuracy Score:',accuracy_score(Y_test, predictions))
print("Precision:",metrics.precision_score(Y_test, predictions))
print("Recall:",metrics.recall_score(Y_test,predictions ))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        22
#
#     accuracy                           1.00        22
#    macro avg       1.00      1.00      1.00        22
# weighted avg       1.00      1.00      1.00        22
#
# Confusion Matrix:
#  [[22]]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-80-c4e911709df3> in <module>
#       1 print('Classification Report:\n',classification_report(Y_test, predictions))
#       2 print('Confusion Matrix:\n',confusion_matrix(Y_test, predictions))
# ----> 3 print('Accuracy Score:',accuracy_score(Y_test, predictions))
#       4 print("Precision:",metrics.precision_score(Y_test, predictions))
#       5 print("Recall:",metrics.recall_score(Y_test,predictions ))
#
# NameError: name 'accuracy_score' is not defined

# %%
#Svm linear kernel
from sklearn.svm import SVC
svc_linear=SVC(kernel='linear',random_state=0)
svc_linear.fit(X_train,Y_train)
print('Svc  linear fernel accuracy:', svc_linear.score(X_train,Y_train))
# Out:
# Svc  linear fernel accuracy: 1.0

# %%
predictions=svc_linear.predict(X_test)
from sklearn.metrics import classification_report
classification_report (Y_test,predictions)
# Out:
# '              precision    recall  f1-score   support\n\n           1       1.00      1.00      1.00        22\n\n    accuracy                           1.00        22\n   macro avg       1.00      1.00      1.00        22\nweighted avg       1.00      1.00      1.00        22\n'

# %%
from sklearn.model_selection import cross_val_score
svc_linear=SVC(kernel='linear',random_state=0)
print(cross_val_score(svc_linear,X,Y,cv=5,scoring='accuracy').mean())
# Out:
# nan
# C:\Users\DCL\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:670: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(("The least populated class in y has only %d"
# C:\Users\DCL\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\DCL\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\DCL\anaconda3\lib\site-packages\sklearn\svm\_base.py", line 164, in fit
#     y = self._validate_targets(y)
#   File "C:\Users\DCL\anaconda3\lib\site-packages\sklearn\svm\_base.py", line 549, in _validate_targets
#     raise ValueError(
# ...

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(Y_test,predictions)
# Out:
# array([[22]], dtype=int64)

# %%
from sklearn.svm import SVC
svc_rbf=SVC(kernel='rbf',random_state=0)
svc_rbf.fit(X_train,Y_train)
print('Svc rbf accuracy:', svc_rbf.score(X_train,Y_train))
# Out:
# Svc rbf accuracy: 0.9885057471264368

# %%
predictions=svc_rbf.predict(X_test)
from sklearn.metrics import classification_report
classification_report (Y_test,predictions)
# Out:
# '              precision    recall  f1-score   support\n\n           1       1.00      1.00      1.00        22\n\n    accuracy                           1.00        22\n   macro avg       1.00      1.00      1.00        22\nweighted avg       1.00      1.00      1.00        22\n'

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(Y_test,predictions)
# Out:
# array([[22]], dtype=int64)

# %%
 #Naive_bayes(gaussianNB)
from sklearn.naive_bayes import GaussianNB
naive_gau=GaussianNB()
naive_gau.fit(X_train,Y_train)
print('naive_bayes accuracy:',  naive_gau.score(X_train,Y_train))
# Out:
# naive_bayes accuracy: 1.0

# %%
predictions=naive_gau.predict(X_test)
from sklearn.metrics import classification_report
classification_report (Y_test,predictions)
# Out:
# '              precision    recall  f1-score   support\n\n           1       1.00      1.00      1.00        22\n\n    accuracy                           1.00        22\n   macro avg       1.00      1.00      1.00        22\nweighted avg       1.00      1.00      1.00        22\n'

# %%
from sklearn.model_selection import cross_val_score
naive_gau=GaussianNB()
print(cross_val_score(naive_gau,X,Y,cv=5,scoring='accuracy'))
# Out:
# [1.         1.         1.         0.95454545 1.        ]
# C:\Users\DCL\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:670: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(("The least populated class in y has only %d"

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(Y_test,predictions)
# Out:
# array([[22]], dtype=int64)

# %%
# decision tree
from sklearn.tree import DecisionTreeClassifier
tree=DecisionTreeClassifier(criterion='entropy',random_state=0)
tree.fit(X_train,Y_train)
print('decision tree accuracy:', tree.score(X_train,Y_train))
# Out:
# decision tree accuracy: 1.0

# %%
predictions=tree.predict(X_test)
from sklearn.metrics import classification_report
classification_report (Y_test,predictions)
# Out:
# '              precision    recall  f1-score   support\n\n           1       1.00      1.00      1.00        22\n\n    accuracy                           1.00        22\n   macro avg       1.00      1.00      1.00        22\nweighted avg       1.00      1.00      1.00        22\n'

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(Y_test,predictions)
# Out:
# array([[22]], dtype=int64)

# %%
# randomforest
from sklearn.ensemble import RandomForestClassifier
forest=RandomForestClassifier(n_estimators=10,criterion='entropy',random_state=0)
forest.fit(X_train,Y_train)
print('random forest classifier accuracy:', forest.score(X_train,Y_train))
# Out:
# random forest classifier accuracy: 1.0

# %%
predictions=forest.predict(X_test)
from sklearn.metrics import classification_report
classification_report (Y_test,predictions)
# Out:
# '              precision    recall  f1-score   support\n\n           1       1.00      1.00      1.00        22\n\n    accuracy                           1.00        22\n   macro avg       1.00      1.00      1.00        22\nweighted avg       1.00      1.00      1.00        22\n'

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(Y_test,predictions)
# Out:
# array([[22]], dtype=int64)
